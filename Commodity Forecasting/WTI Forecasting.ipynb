# %%
import eia
import pandas as pd
import requests
import json

import urllib3
from urllib.request import urlopen

# %% [markdown]
# ### Data Retrieval through API connector to EIA

# %%
eia_key = "340d4d6e61d32840dd8d66e2185a675c"

# %%
def eia_search(query):
    api_key = eia_key
    url = 'http://api.eia.gov/series/?api_key=' + api_key
    series_id = query.replace(' ', '%20')
    final_url = url + "&series_id=" + series_id
    json_obj = urlopen(final_url)
    return json.load(json_obj)

# %%
eia_search('PET.RWTC.D')
# Out:
# {'request': {'command': 'series', 'series_id': 'PET.RWTC.D'},
#  'series': [{'copyright': 'Thomson-Reuters',
#    'data': [['20180521', 72.26],
#     ['20180518', 71.23],
#     ['20180517', 71.47],
#     ['20180516', 71.43],
#     ['20180515', 71.34],
#     ['20180514', 71.01],
#     ['20180511', 70.69],
#     ['20180510', 71.36],
#     ['20180509', 71.16],
#     ['20180508', 68.83],
#     ['20180507', 70.74],
#     ['20180504', 69.71],
#     ['20180503', 68.45],
#     ['20180502', 67.91],
#     ['20180501', 67.28],
#     ['20180430', 68.56],
#     ['20180427', 68.11],
#     ['20180426', 68.18],
#     ['20180425', 68],
#     ['20180424', 67.66],
#     ['20180423', 67.61],
#     ['20180420', 68.26],
#     ['20180419', 68.3],
#     ['20180418', 68.44],
#     ['20180417', 66.5],
#     ['20180416', 66.23],
#     ['20180413', 67.35],
#     ['20180412', 67.07],
#     ['20180411', 66.81],
#     ['20180410', 65.48],
#     ['20180409', 63.4],
#     ['20180406', 62.03],
#     ['20180405', 63.53],
#     ['20180404', 63.35],
#     ['20180403', 63.41],
#     ['20180402', 63.05],
#     ['20180329', 64.87],
#     ['20180328', 64.3],
#     ['20180327', 65.21],
#     ['20180326', 65.49],
#     ['20180323', 65.8],
#     ['20180322', 64.25],
#     ['20180321', 65.1],
#     ['20180320', 63.37],
#     ['20180319', 62.01],
#     ['20180316', 62.29],
#     ['20180315', 61.16],
#     ['20180314', 60.89],
#     ['20180313', 60.69],
#     ['20180312', 61.35],
#     ['20180309', 62.02],
#     ['20180308', 60.13],
#     ['20180307', 61.09],
#     ['20180306', 62.54],
#     ['20180305', 62.49],
#     ['20180302', 61.19],
#     ['20180301', 60.98],
#     ['20180228', 61.43],
#     ['20180227', 62.94],
#     ['20180226', 63.81],
#     ['20180223', 63.52],
#     ['20180222', 62.72],
#     ['20180221', 61.73],
#     ['20180220', 61.91],
#     ['20180216', 61.89],
#     ['20180215', 61.48],
#     ['20180214', 60.7],
#     ['20180213', 59.33],
#     ['20180212', 59.41],
#     ['20180209', 59.2],
#     ['20180208', 61.3],
#     ['20180207', 61.91],
#     ['20180206', 63.48],
#     ['20180205', 64.18],
#     ['20180202', 65.5],
#     ['20180201', 65.92],
#     ['20180131', 64.82],
#     ['20180130', 64.64],
#     ['20180129', 65.71],
#     ['20180126', 66.27],
#     ['20180125', 65.62],
#     ['20180124', 65.69],
#     ['20180123', 64.45],
#     ['20180122', 63.66],
#     ['20180119', 63.38],
#     ['20180118', 63.96],
#     ['20180117', 63.92],
#     ['20180116', 63.82],
#     ['20180112', 64.22],
#     ['20180111', 63.81],
#     ['20180110', 63.6],
#     ['20180109', 62.92],
#     ['20180108', 61.73],
#     ['20180105', 61.49],
#     ['20180104', 61.98],
#     ['20180103', 61.61],
#     ['20180102', 60.37],
#     ['20171229', 60.46],
#     ['20171228', 59.84],
#     ['20171227', 59.67],
#     ['20171226', 59.55],
#     ['20171222', 58.25],
#     ['20171221', 58.34],
#     ['20171220', 58.09],
#     ['20171219', 57.49],
#     ['20171218', 57.17],
#     ['20171215', 57.29],
#     ['20171214', 57],
#     ['20171213', 56.59],
#     ['20171212', 57.12],
#     ['20171211', 57.84],
#     ['20171208', 57.15],
#     ['20171207', 56.5],
#     ['20171206', 55.79],
#     ['20171205', 57.66],
#     ['20171204', 57.48],
#     ['20171201', 58.35],
#     ['20171130', 57.4],
#     ['20171129', 57.25],
#     ['20171128', 57.96],
#     ['20171127', 58.1],
#     ['20171124', 58.94],
#     ['20171122', 57.88],
#     ['20171121', 56.84],
#     ['20171120', 56.21],
#     ['20171117', 56.21],
#     ['20171116', 55.14],
#     ['20171115', 55.28],
#     ['20171114', 55.67],
#     ['20171113', 56.77],
#     ['20171110', 56.75],
#     ['20171109', 57.16],
#     ['20171108', 56.82],
#     ['20171107', 57.19],
#     ['20171106', 57.34],
#     ['20171103', 55.63],
#     ['20171102', 54.55],
#     ['20171101', 54.32],
#     ['20171031', 54.36],
#     ['20171030', 54.11],
#     ['20171027', 53.92],
#     ['20171026', 52.41],
#     ['20171025', 51.97],
#     ['20171024', 52.32],
#     ['20171023', 51.91],
#     ['20171020', 51.63],
#     ['20171019', 51.29],
#     ['20171018', 52.05],
#     ['20171017', 51.87],
#     ['20171016', 51.86],
#     ['20171013', 51.43],
#     ['20171012', 50.61],
#     ['20171011', 51.3],
#     ['20171010', 50.93],
#     ['20171009', 49.58],
#     ['20171006', 49.34],
#     ['20171005', 50.79],
#     ['20171004', 50],
#     ['20171003', 50.44],
#     ['20171002', 50.59],
#     ['20170929', 51.67],
#     ['20170928', 51.62],
#     ['20170927', 52.14],
#     ['20170926', 51.59],
#     ['20170925', 51.85],
#     ['20170922', 50.33],
#     ['20170921', 50.58],
#     ['20170920', 50.29],
#     ['20170919', 49.54],
#     ['20170918', 49.88],
#     ['20170915', 49.9],
#     ['20170914', 49.86],
#     ['20170913', 49.3],
#     ['20170912', 48.21],
#     ['20170911', 48.06],
#     ['20170908', 47.44],
#     ['20170907', 49.1],
#     ['20170906', 49.13],
#     ['20170905', 48.63],
#     ['20170901', 47.32],
#     ['20170831', 47.26],
#     ['20170830', 45.96],
#     ['20170829', 46.46],
#     ['20170828', 46.4],
#     ['20170825', 47.65],
#     ['20170824', 47.24],
#     ['20170823', 48.45],
#     ['20170822', 47.65],
#     ['20170821', 47.39],
#     ['20170818', 48.59],
#     ['20170817', 47.07],
#     ['20170816', 46.8],
#     ['20170815', 47.57],
#     ['20170814', 47.59],
#     ['20170811', 48.81],
#     ['20170810', 48.54],
#     ['20170809', 49.59],
#     ['20170808', 49.07],
#     ['20170807', 49.37],
#     ['20170804', 49.57],
#     ['20170803', 49.03],
#     ['20170802', 49.6],
#     ['20170801', 49.19],
#     ['20170731', 50.21],
#     ['20170728', 49.72],
#     ['20170727', 49.05],
#     ['20170726', 48.58],
#     ['20170725', 47.77],
#     ['20170724', 46.21],
#     ['20170721', 45.78],
#     ['20170720', 46.73],
#     ['20170719', 47.1],
#     ['20170718', 46.4],
#     ['20170717', 46.02],
#     ['20170714', 46.53],
#     ['20170713', 46.06],
#     ['20170712', 45.48],
#     ['20170711', 45.06],
#     ['20170710', 44.4],
#     ['20170707', 44.25],
#     ['20170706', 45.52],
#     ['20170705', 45.11],
#     ['20170630', 46.02],
#     ['20170629', 44.88],
#     ['20170628', 44.74],
#     ['20170627', 44.25],
#     ['20170626', 43.24],
#     ['20170623', 42.86],
#     ['20170622', 42.53],
#     ['20170621', 42.48],
#     ['20170620', 43.34],
#     ['20170619', 44.24],
#     ['20170616', 44.73],
#     ['20170615', 44.47],
#     ['20170614', 44.79],
#     ['20170613', 46.41],
#     ['20170612', 46.1],
#     ['20170609', 45.82],
#     ['20170608', 45.68],
#     ['20170607', 45.8],
#     ['20170606', 48.13],
#     ['20170605', 47.4],
#     ['20170602', 47.68],
#     ['20170601', 48.32],
#     ['20170531', 48.29],
#     ['20170530', 49.63],
#     ['20170526', 49.58],
#     ['20170525', 48.57],
#     ['20170524', 50.99],
#     ['20170523', 51.12],
#     ['20170522', 50.81],
#     ['20170519', 50.32],
#     ['20170518', 49.36],
#     ['20170517', 49.04],
#     ['20170516', 48.64],
#     ['20170515', 48.86],
#     ['20170512', 47.83],
#     ['20170511', 47.81],
#     ['20170510', 47.28],
#     ['20170509', 45.84],
#     ['20170508', 46.46],
#     ['20170505', 46.23],
#     ['20170504', 45.55],
#     ['20170503', 47.79],
#     ['20170502', 47.65],
#     ['20170501', 48.83],
#     ['20170428', 49.31],
#     ['20170427', 48.96],
#     ['20170426', 49.22],
#     ['20170425', 49.22],
#     ['20170424', 48.9],
#     ['20170421', 49.64],
#     ['20170420', 50.26],
#     ['20170419', 50.49],
#     ['20170418', 52.46],
#     ['20170417', 52.62],
#     ['20170413', 53.19],
#     ['20170412', 53.12],
#     ['20170411', 53.38],
#     ['20170410', 53.06],
#     ['20170407', 52.25],
#     ['20170406', 51.69],
#     ['20170405', 51.14],
#     ['20170404', 50.99],
#     ['20170403', 50.25],
#     ['20170331', 50.54],
#     ['20170330', 50.3],
#     ['20170329', 49.47],
#     ['20170328', 48.36],
#     ['20170327', 47.02],
#     ['20170324', 47.3],
#     ['20170323', 47],
#     ['20170322', 47.29],
#     ['20170321', 47.02],
#     ['20170320', 47.79],
#     ['20170317', 48.34],
#     ['20170316', 48.3],
#     ['20170315', 48.34],
#     ['20170314', 47.24],
#     ['20170313', 47.95],
#     ['20170310', 48.05],
#     ['20170309', 48.75],
#     ['20170308', 49.83],
#     ['20170307', 52.68],
#     ['20170306', 53.19],
#     ['20170303', 53.33],
#     ['20170302', 52.63],
#     ['20170301', 53.82],
#     ['20170228', 54],
#     ['20170227', 54.04],
#     ['20170224', 53.99],
#     ['20170223', 54.48],
#     ['20170222', 53.61],
#     ['20170221', 54.02],
#     ['20170217', 53.41],
#     ['20170216', 53.41],
#     ['20170215', 53.11],
#     ['20170214', 53.21],
#     ['20170213', 52.96],
#     ['20170210', 53.84],
#     ['20170209', 52.99],
#     ['20170208', 52.37],
#     ['20170207', 52.19],
#     ['20170206', 53.01],
#     ['20170203', 53.81],
#     ['20170202', 53.55],
#     ['20170201', 53.9],
#     ['20170131', 52.75],
#     ['20170130', 52.63],
#     ['20170127', 53.18],
#     ['20170126', 53.24],
#     ['20170125', 52.14],
#     ['20170124', 52.38],
#     ['20170123', 52.77],
#     ['20170120', 52.33],
#     ['20170119', 51.39],
#     ['20170118', 51.12],
#     ['20170117', 52.45],
#     ['20170113', 52.36],
#     ['20170112', 53.01],
#     ['20170111', 52.19],
#     ['20170110', 50.82],
#     ['20170109', 51.95],
#     ['20170106', 53.98],
#     ['20170105', 53.77],
#     ['20170104', 53.26],
#     ['20170103', 52.36],
#     ['20161230', 53.75],
#     ['20161229', 53.8],
#     ['20161228', 54.01],
#     ['20161227', 52.82],
#     ['20161223', 52.01],
#     ['20161222', 51.98],
#     ['20161221', 51.44],
#     ['20161220', 52.22],
#     ['20161219', 52.13],
#     ['20161216', 51.93],
#     ['20161215', 50.9],
#     ['20161214', 51.01],
#     ['20161213', 52.99],
#     ['20161212', 52.74],
#     ['20161209', 51.51],
#     ['20161208', 50.84],
#     ['20161207', 49.85],
#     ['20161206', 50.95],
#     ['20161205', 51.72],
#     ['20161202', 51.7],
#     ['20161201', 51.08],
#     ['20161130', 49.41],
#     ['20161129', 45.29],
#     ['20161128', 45.66],
#     ['20161125', 46.72],
#     ['20161123', 46.72],
#     ['20161122', 48.07],
#     ['20161121', 47.48],
#     ['20161118', 45.69],
#     ['20161117', 45.37],
#     ['20161116', 45.56],
#     ['20161115', 45.86],
#     ['20161114', 43.29],
#     ['20161111', 43.39],
#     ['20161110', 44.62],
#     ['20161109', 45.2],
#     ['20161108', 44.96],
#     ['20161107', 44.88],
#     ['20161104', 44.07],
#     ['20161103', 44.66],
#     ['20161102', 45.32],
#     ['20161101', 46.66],
#     ['20161031', 46.83],
#     ['20161028', 48.72],
#     ['20161027', 49.71],
#     ['20161026', 48.75],
#     ['20161025', 49.45],
#     ['20161024', 50.18],
#     ['20161021', 50.61],
#     ['20161020', 50.31],
#     ['20161019', 51.59],
#     ['20161018', 50.3],
#     ['20161017', 49.97],
#     ['20161014', 50.35],
#     ['20161013', 50.47],
#     ['20161012', 50.14],
#     ['20161011', 50.72],
#     ['20161010', 49.76],
#     ['20161007', 49.76],
#     ['20161006', 50.44],
#     ['20161005', 49.75],
#     ['20161004', 48.67],
#     ['20161003', 48.8],
#     ['20160930', 47.72],
#     ['20160929', 47.72],
#     ['20160928', 47.07],
#     ['20160927', 44.65],
#     ['20160926', 45.6],
#     ['20160923', 44.36],
#     ['20160922', 46.1],
#     ['20160921', 45.33],
#     ['20160920', 43.85],
#     ['20160919', 43.34],
#     ['20160916', 43.04],
#     ['20160915', 43.85],
#     ['20160914', 43.62],
#     ['20160913', 44.91],
#     ['20160912', 46.28],
#     ['20160909', 45.88],
#     ['20160908', 47.63],
#     ['20160907', 45.47],
#     ['20160906', 44.85],
#     ['20160905', 44.39],
#     ['20160902', 44.39],
#     ['20160901', 43.17],
#     ['20160831', 44.68],
#     ['20160830', 46.32],
#     ['20160829', 46.97],
#     ['20160826', 47.64],
#     ['20160825', 46.97],
#     ['20160824', 46.29],
#     ['20160823', 47.54],
#     ['20160822', 46.8],
#     ['20160819', 48.48],
#     ['20160818', 48.2],
#     ['20160817', 46.81],
#     ['20160816', 46.57],
#     ['20160815', 45.72],
#     ['20160812', 44.47],
#     ['20160811', 43.51],
#     ['20160810', 41.75],
#     ['20160809', 42.78],
#     ['20160808', 43.06],
#     ['20160805', 41.83],
#     ['20160804', 41.92],
#     ['20160803', 40.8],
#     ['20160802', 39.5],
#     ['20160801', 40.05],
#     ['20160729', 41.54],
#     ['20160728', 41.13],
#     ['20160727', 41.9],
#     ['20160726', 42.16],
#     ['20160725', 42.4],
#     ['20160722', 43.41],
#     ['20160721', 43.96],
#     ['20160720', 44.96],
#     ['20160719', 44.64],
#     ['20160718', 45.23],
#     ['20160715', 45.93],
#     ['20160714', 45.64],
#     ['20160713', 44.87],
#     ['20160712', 46.82],
#     ['20160711', 44.73],
#     ['20160708', 45.37],
#     ['20160707', 45.22],
#     ['20160706', 47.37],
#     ['20160705', 46.73],
#     ['20160701', 49.02],
#     ['20160630', 48.27],
#     ['20160629', 49.85],
#     ['20160628', 47.93],
#     ['20160627', 45.8],
#     ['20160624', 46.7],
#     ['20160623', 49.34],
#     ['20160622', 49.16],
#     ['20160621', 48.95],
#     ['20160620', 49.4],
#     ['20160617', 48],
#     ['20160616', 46.14],
#     ['20160615', 47.92],
#     ['20160614', 48.49],
#     ['20160613', 48.89],
#     ['20160610', 49.09],
#     ['20160609', 50.52],
#     ['20160608', 51.23],
#     ['20160607', 50.37],
#     ['20160606', 49.71],
#     ['20160603', 48.69],
#     ['20160602', 49.14],
#     ['20160601', 49.07],
#     ['20160531', 49.1],
#     ['20160527', 49.36],
#     ['20160526', 49],
#     ['20160525', 49.1],
#     ['20160524', 48.04],
#     ['20160523', 48.12],
#     ['20160520', 47.67],
#     ['20160519', 48.16],
#     ['20160518', 48.12],
#     ['20160517', 48.29],
#     ['20160516', 47.72],
#     ['20160513', 46.22],
#     ['20160512', 46.64],
#     ['20160511', 46.21],
#     ['20160510', 44.68],
#     ['20160509', 43.45],
#     ['20160506', 44.58],
#     ['20160505', 44.33],
#     ['20160504', 43.77],
#     ['20160503', 43.65],
#     ['20160502', 44.75],
#     ['20160429', 45.98],
#     ['20160428', 46.03],
#     ['20160427', 45.29],
#     ['20160426', 42.52],
#     ['20160425', 41.67],
#     ['20160422', 42.76],
#     ['20160421', 43.18],
#     ['20160420', 42.72],
#     ['20160419', 40.88],
#     ['20160418', 39.74],
#     ['20160415', 40.4],
#     ['20160414', 41.45],
#     ['20160413', 41.7],
#     ['20160412', 42.12],
#     ['20160411', 40.46],
#     ['20160408', 39.74],
#     ['20160407', 37.3],
#     ['20160406', 37.74],
#     ['20160405', 34.52],
#     ['20160404', 34.3],
#     ['20160401', 35.36],
#     ['20160331', 36.94],
#     ['20160330', 36.91],
#     ['20160329', 36.91],
#     ['20160328', 37.99],
#     ['20160324', 38.14],
#     ['20160323', 38.28],
#     ['20160322', 41.45],
#     ['20160321', 39.91],
#     ['20160318', 39.47],
#     ['20160317', 40.17],
#     ['20160316', 38.43],
#     ['20160315', 36.32],
#     ['20160314', 37.2],
#     ['20160311', 38.51],
#     ['20160310', 37.77],
#     ['20160309', 37.62],
#     ['20160308', 36.67],
#     ['20160307', 37.9],
#     ['20160304', 35.91],
#     ['20160303', 34.56],
#     ['20160302', 34.57],
#     ['20160301', 34.39],
#     ['20160229', 32.74],
#     ['20160226', 31.65],
#     ['20160225', 31.4],
#     ['20160224', 30.35],
#     ['20160223', 31.84],
#     ['20160222', 31.37],
#     ['20160219', 29.59],
#     ['20160218', 30.77],
#     ['20160217', 30.68],
#     ['20160216', 29.05],
#     ['20160212', 29.32],
#     ['20160211', 26.19],
#     ['20160210', 27.54],
#     ['20160209', 27.96],
#     ['20160208', 29.71],
#     ['20160205', 30.86],
#     ['20160204', 31.63],
#     ['20160203', 32.29],
#     ['20160202', 29.9],
#     ['20160201', 31.62],
#     ['20160129', 33.66],
#     ['20160128', 33.21],
#     ['20160127', 32.32],
#     ['20160126', 29.54],
#     ['20160125', 30.31],
#     ['20160122', 32.07],
#     ['20160121', 29.55],
#     ['20160120', 26.68],
#     ['20160119', 28.47],
#     ['20160115', 29.45],
#     ['20160114', 31.22],
#     ['20160113', 30.42],
#     ['20160112', 30.42],
#     ['20160111', 31.42],
#     ['20160108', 33.2],
#     ['20160107', 33.29],
#     ['20160106', 33.97],
#     ['20160105', 35.97],
#     ['20160104', 36.81],
#     ['20160101', 37.13],
#     ['20151231', 37.13],
#     ['20151230', 36.59],
#     ['20151229', 37.88],
#     ['20151228', 36.36],
#     ['20151225', 37.6],
#     ['20151224', 37.62],
#     ['20151223', 36.76],
#     ['20151222', 36.12],
#     ['20151221', 34.55],
#     ['20151218', 34.72],
#     ['20151217', 34.98],
#     ['20151216', 35.55],
#     ['20151215', 37.32],
#     ['20151214', 36.31],
#     ['20151211', 35.65],
#     ['20151210', 36.76],
#     ['20151209', 37.16],
#     ['20151208', 37.46],
#     ['20151207', 37.64],
#     ['20151204', 40],
#     ['20151203', 41.08],
#     ['20151202', 39.93],
#     ['20151201', 40.58],
#     ['20151130', 40.43],
#     ['20151127', 40.57],
#     ['20151126', 41.22],
#     ['20151125', 41.22],
#     ['20151124', 40.89],
#     ['20151123', 39.27],
#     ['20151120', 39.39],
#     ['20151119', 40.55],
#     ['20151118', 40.75],
#     ['20151117', 40.73],
#     ['20151116', 41.68],
#     ['20151113', 40.69],
#     ['20151112', 41.74],
#     ['20151111', 42.95],
#     ['20151110', 44.23],
#     ['20151109', 43.87],
#     ['20151106', 44.32],
#     ['20151105', 45.27],
#     ['20151104', 46.32],
#     ['20151103', 47.88],
#     ['20151102', 46.12],
#     ['20151030', 46.6],
#     ['20151029', 46.02],
#     ['20151028', 45.93],
#     ['20151027', 43.21],
#     ['20151026', 43.19],
#     ['20151023', 43.91],
#     ['20151022', 44.9],
#     ['20151021', 45.22],
#     ['20151020', 45.84],
#     ['20151019', 45.91],
#     ['20151016', 47.3],
#     ['20151015', 46.38],
#     ['20151014', 46.63],
#     ['20151013', 46.7],
#     ['20151012', 47.09],
#     ['20151009', 49.67],
#     ['20151008', 49.46],
#     ['20151007', 47.86],
#     ['20151006', 48.53],
#     ['20151005', 46.28],
#     ['20151002', 45.54],
#     ['20151001', 44.75],
#     ['20150930', 45.06],
#     ['20150929', 45.24],
#     ['20150928', 44.4],
#     ['20150925', 45.55],
#     ['20150924', 44.94],
#     ['20150923', 44.53],
#     ['20150922', 46.17],
#     ['20150921', 46.67],
#     ['20150918', 44.71],
#     ['20150917', 46.93],
#     ['20150916', 47.12],
#     ['20150915', 44.58],
#     ['20150914', 44.07],
#     ['20150911', 44.75],
#     ['20150910', 45.85],
#     ['20150909', 44.13],
#     ['20150908', 45.92],
#     ['20150904', 46.02],
#     ['20150903', 46.75],
#     ['20150902', 46.3],
#     ['20150901', 45.38],
#     ['20150831', 49.2],
#     ['20150828', 45.29],
#     ['20150827', 42.47],
#     ['20150826', 38.5],
#     ['20150825', 39.15],
#     ['20150824', 38.22],
#     ['20150821', 40.45],
#     ['20150820', 41],
#     ['20150819', 40.75],
#     ['20150818', 42.58],
#     ['20150817', 41.93],
#     ['20150814', 42.45],
#     ['20150813', 42.27],
#     ['20150812', 43.22],
#     ['20150811', 43.11],
#     ['20150810', 44.94],
#     ['20150807', 43.87],
#     ['20150806', 44.69],
#     ['20150805', 45.13],
#     ['20150804', 45.75],
#     ['20150803', 45.25],
#     ['20150731', 47.11],
#     ['20150730', 48.53],
#     ['20150729', 48.77],
#     ['20150728', 47.97],
#     ['20150727', 47.17],
#     ['20150724', 47.98],
#     ['20150723', 48.11],
#     ['20150722', 49.27],
#     ['20150721', 50.59],
#     ['20150720', 50.11],
#     ['20150717', 50.88],
#     ['20150716', 50.9],
#     ['20150715', 51.4],
#     ['20150714', 53.05],
#     ['20150713', 52.19],
#     ['20150710', 52.74],
#     ['20150709', 52.76],
#     ['20150708', 51.61],
#     ['20150707', 52.33],
#     ['20150706', 52.48],
#     ['20150702', 56.93],
#     ['20150701', 56.94],
#     ['20150630', 59.48],
#     ['20150629', 58.34],
#     ['20150626', 59.41],
#     ['20150625', 59.59],
#     ['20150624', 60.01],
#     ['20150623', 61.05],
#     ['20150622', 60.01],
#     ['20150619', 59.62],
#     ['20150618', 60.41],
#     ['20150617', 59.89],
#     ['20150616', 60.01],
#     ['20150615', 59.53],
#     ['20150612', 59.96],
#     ['20150611', 60.74],
#     ['20150610', 61.36],
#     ['20150609', 60.15],
#     ['20150608', 58.15],
#     ['20150605', 59.11],
#     ['20150604', 58],
#     ['20150603', 59.67],
#     ['20150602', 61.3],
#     ['20150601', 60.24],
#     ['20150529', 60.25],
#     ['20150528', 57.69],
#     ['20150527', 57.51],
#     ['20150526', 57.29],
#     ['20150522', 58.88],
#     ['20150521', 60.18],
#     ['20150520', 58.96],
#     ['20150519', 57.3],
#     ['20150518', 59.44],
#     ['20150515', 59.73],
#     ['20150514', 59.89],
#     ['20150513', 60.5],
#     ['20150512', 60.72],
#     ['20150511', 59.23],
#     ['20150508', 59.41],
#     ['20150507', 58.99],
#     ['20150506', 60.93],
#     ['20150505', 60.38],
#     ['20150504', 58.92],
#     ['20150501', 59.1],
#     ['20150430', 59.62],
#     ['20150429', 58.55],
#     ['20150428', 57.05],
#     ['20150427', 55.56],
#     ['20150424', 55.98],
#     ['20150423', 56.59],
#     ['20150422', 56.17],
#     ['20150421', 55.58],
#     ['20150420', 56.37],
#     ['20150417', 55.71],
#     ['20150416', 56.69],
#     ['20150415', 56.25],
#     ['20150414', 53.3],
#     ['20150413', 51.95],
#     ['20150410', 51.63],
#     ['20150409', 50.79],
#     ['20150408', 50.44],
#     ['20150407', 53.95],
#     ['20150406', 52.08],
#     ['20150402', 49.13],
#     ['20150401', 50.12],
#     ['20150331', 47.72],
#     ['20150330', 48.66],
#     ['20150327', 48.83],
#     ['20150326', 51.41],
#     ['20150325', 48.75],
#     ['20150324', 47.03],
#     ['20150323', 47.4],
#     ['20150320', 46],
#     ['20150319', 44.02],
#     ['20150318', 44.63],
#     ['20150317', 43.39],
#     ['20150316', 43.93],
#     ['20150313', 44.88],
#     ['20150312', 47.12],
#     ['20150311', 48.06],
#     ['20150310', 48.42],
#     ['20150309', 49.95],
#     ['20150306', 49.61],
#     ['20150305', 50.76],
#     ['20150304', 51.53],
#     ['20150303', 50.43],
#     ['20150302', 49.59],
#     ['20150227', 49.84],
#     ['20150226', 47.65],
#     ['20150225', 50.25],
#     ['20150224', 48.48],
#     ['20150223', 49.56],
#     ['20150220', 49.95],
#     ['20150219', 51.12],
#     ['20150218', 52.13],
#     ['20150217', 53.56],
#     ['20150213', 52.66],
#     ['20150212', 51.17],
#     ['20150211', 48.8],
#     ['20150210', 50.06],
#     ['20150209', 52.99],
#     ['20150206', 51.66],
#     ['20150205', 50.48],
#     ['20150204', 48.45],
#     ['20150203', 53.04],
#     ['20150202', 49.25],
#     ['20150130', 47.79],
#     ['20150129', 44.12],
#     ['20150128', 44.08],
#     ['20150127', 45.84],
#     ['20150126', 44.8],
#     ['20150123', 45.26],
#     ['20150122', 45.93],
#     ['20150121', 47.85],
#     ['20150120', 46.79],
#     ['20150116', 48.49],
#     ['20150115', 46.37],
#     ['20150114', 48.49],
#     ['20150113', 45.92],
#     ['20150112', 46.06],
#     ['20150109', 48.35],
#     ['20150108', 48.8],
#     ['20150107', 48.69],
#     ['20150106', 47.98],
#     ['20150105', 50.05],
#     ['20150102', 52.72],
#     ['20141231', 53.45],
#     ['20141230', 54.14],
#     ['20141229', 53.46],
#     ['20141226', 54.59],
#     ['20141224', 55.7],
#     ['20141223', 56.78],
#     ['20141222', 55.25],
#     ['20141219', 56.91],
#     ['20141218', 54.18],
#     ['20141217', 56.43],
#     ['20141216', 55.97],
#     ['20141215', 55.96],
#     ['20141212', 57.81],
#     ['20141211', 60.01],
#     ['20141210', 60.99],
#     ['20141209', 63.74],
#     ['20141208', 63.13],
#     ['20141205', 65.89],
#     ['20141204', 66.73],
#     ['20141203', 67.3],
#     ['20141202', 66.99],
#     ['20141201', 68.98],
#     ['20141128', 65.94],
#     ['20141126', 73.7],
#     ['20141125', 74.04],
#     ['20141124', 75.74],
#     ['20141121', 76.52],
#     ['20141120', 75.63],
#     ['20141119', 74.55],
#     ['20141118', 74.55],
#     ['20141117', 75.64],
#     ['20141114', 75.91],
#     ['20141113', 74.13],
#     ['20141112', 77.16],
#     ['20141111', 77.85],
#     ['20141110', 77.43],
#     ['20141107', 78.71],
#     ['20141106', 77.87],
#     ['20141105', 78.71],
#     ['20141104', 77.15],
#     ['20141103', 78.77],
#     ['20141031', 80.53],
#     ['20141030', 81.06],
#     ['20141029', 82.25],
#     ['20141028', 81.36],
#     ['20141027', 81.26],
#     ['20141024', 81.27],
#     ['20141023', 82.81],
#     ['20141022', 80.52],
#     ['20141021', 83.25],
#     ['20141020', 82.76],
#     ['20141017', 82.8],
#     ['20141016', 82.33],
#     ['20141015', 81.82],
#     ['20141014', 81.72],
#     ['20141013', 85.73],
#     ['20141010', 85.87],
#     ['20141009', 85.76],
#     ['20141008', 87.29],
#     ['20141007', 88.89],
#     ['20141006', 90.33],
#     ['20141003', 89.76],
#     ['20140929', 94.53],
#     ['20140926', 95.55],
#     ['20140925', 93.59],
#     ['20140924', 93.6],
#     ['20140923', 91.55],
#     ['20140922', 91.46],
#     ['20140919', 92.43],
#     ['20140918', 93.07],
#     ['20140917', 94.33],
#     ['20140916', 94.91],
#     ['20140915', 92.86],
#     ['20140912', 92.18],
#     ['20140911', 92.89],
#     ['20140910', 91.71],
#     ['20140909', 92.73],
#     ['20140908', 92.64],
#     ['20140905', 93.32],
#     ['20140904', 94.51],
#     ['20140903', 95.5],
#     ['20140902', 92.92],
#     ['20140829', 97.86],
#     ['20140828', 96.44],
#     ['20140827', 95.82],
#     ['20140826', 95.78],
#     ['20140825', 95.39],
#     ['20140822', 93.61],
#     ['20140821', 93.97],
#     ['20140820', 96.4],
#     ['20140819', 94.35],
#     ['20140818', 96.44],
#     ['20140815', 97.3],
#     ['20140814', 95.54],
#     ['20140813', 97.57],
#     ['20140812', 97.36],
#     ['20140811', 98.09],
#     ['20140808', 97.61],
#     ['20140807', 97.34],
#     ['20140806', 96.93],
#     ['20140805', 97.34],
#     ['20140804', 98.26],
#     ['20140801', 97.86],
#     ['20140731', 98.23],
#     ['20140730', 104.29],
#     ['20140729', 104.91],
#     ['20140728', 105.68],
#     ['20140725', 105.23],
#     ['20140724', 102.76],
#     ['20140723', 103.81],
#     ['20140722', 104.59],
#     ['20140721', 105.34],
#     ['20140718', 103.83],
#     ['20140717', 103.84],
#     ['20140716', 101.88],
#     ['20140715', 100.56],
#     ['20140714', 101.73],
#     ['20140711', 101.48],
#     ['20140710', 103.61],
#     ['20140709', 102.93],
#     ['20140708', 104.06],
#     ['20140707', 104.19],
#     ['20140703', 104.76],
#     ['20140702', 105.18],
#     ['20140701', 106.06],
#     ['20140630', 106.07],
#     ['20140627', 106.46],
#     ['20140626', 106.49],
#     ['20140625', 107.04],
#     ['20140624', 106.64],
#     ['20140623', 106.83],
#     ['20140620', 107.95],
#     ['20140619', 107.08],
#     ['20140618', 106.64],
#     ['20140617', 106.95],
#     ['20140616', 107.52],
#     ['20140613', 107.49],
#     ['20140612', 107.2],
#     ['20140611', 105.04],
#     ['20140610', 105.02],
#     ['20140609', 105.09],
#     ['20140606', 103.32],
#     ['20140605', 103.17],
#     ['20140604', 103.27],
#     ['20140603', 103.34],
#     ...],
#    'description': 'Cushing, OK WTI Spot Price FOB',
#    'end': '20180521',
#    'f': 'D',
#    'geography': 'USA-OK',
#    'iso3166': 'USA-OK',
#    'name': 'Cushing, OK WTI Spot Price FOB, Daily',
#    'series_id': 'PET.RWTC.D',
#    'source': 'Thomson-Reuters',
#    'start': '19860102',
#    'units': 'Dollars per Barrel',
#    'unitsshort': '$/bbl',
#    'updated': '2018-05-23T13:15:35-0400'}]}

# %%
data = eia_search('PET.RWTC.D')

# %% [markdown]
# ### Data Transformation from list to data frame

# %%
data_list = data['series'][0]['data']

# %%
df = pd.DataFrame(data_list)

# %% [markdown]
# ### Renaming Columns to Date and Oil Price

# %%
df.columns = ['date', 'oil_price']

# %% [markdown]
# ### Setting date-time structure to Date variable

# %%
df['date'] = pd.to_datetime(df['date'])

# %% [markdown]
# ### Importing Keras-Tensorflow Libraries

# %%
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.models import Sequential

# %% [markdown]
# ### Importing Train-Test Libraries

# %%
import math
import numpy
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Normalizing Time-series Data

# %%
scaler = MinMaxScaler(feature_range=(0,1))

# %%
dataset = scaler.fit_transform(df)

# %% [markdown]
# ### Split into Train and Test datasets

# %%
train_size = int(len(dataset) * 0.7)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
# Out:
# 5717 2451

# %% [markdown]
# ### Creating Time-lagged (period = 1) column

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %% [markdown]
# ### Building Model

# %%
model = Sequential()

model.add(LSTM(
    input_shape=(None, 1),
    units=50,
    return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(
    100,
    return_sequences=False))
model.add(Dropout(0.2))

model.add(Dense(
    units=1))
model.add(Activation('linear'))

start = time.time()
model.compile(loss='mse', optimizer='rmsprop')

print ('compilation time:'), time.time() - start
# Out:
# compilation time:
# (None, 0.027415037155151367)

# %% [markdown]
# ### Training Model

# %%
model.fit(
    trainX,
    trainY,
    batch_size=512,
    epochs=100,
    validation_split=0.05,
    verbose=2)
# Out:
# /Users/Weiyang/anaconda3/lib/python3.6/site-packages/keras/models.py:981: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Train on 5429 samples, validate on 286 samples
# Epoch 1/100
#  - 3s - loss: 0.3698 - val_loss: 0.0278
# Epoch 2/100
#  - 0s - loss: 0.1910 - val_loss: 6.8446e-04
# Epoch 3/100
#  - 0s - loss: 0.0661 - val_loss: 0.0132
# Epoch 4/100
#  - 0s - loss: 0.0183 - val_loss: 0.0355
# Epoch 5/100
#  - 0s - loss: 0.0122 - val_loss: 0.0357
# Epoch 6/100
#  - 0s - loss: 0.0115 - val_loss: 0.0300
# Epoch 7/100
#  - 0s - loss: 0.0099 - val_loss: 0.0243
# Epoch 8/100
#  - 0s - loss: 0.0081 - val_loss: 0.0204
# Epoch 9/100
#  - 0s - loss: 0.0065 - val_loss: 0.0089
# Epoch 10/100
#  - 0s - loss: 0.0055 - val_loss: 0.0047
# Epoch 11/100
#  - 0s - loss: 0.0048 - val_loss: 0.0043
# Epoch 12/100
#  - 0s - loss: 0.0042 - val_loss: 0.0025
# Epoch 13/100
#  - 0s - loss: 0.0043 - val_loss: 0.0027
# Epoch 14/100
#  - 0s - loss: 0.0038 - val_loss: 0.0013
# Epoch 15/100
#  - 0s - loss: 0.0039 - val_loss: 0.0021
# Epoch 16/100
#  - 0s - loss: 0.0038 - val_loss: 7.2749e-04
# Epoch 17/100
#  - 0s - loss: 0.0037 - val_loss: 0.0012
# Epoch 18/100
#  - 0s - loss: 0.0037 - val_loss: 6.5852e-04
# Epoch 19/100
#  - 0s - loss: 0.0035 - val_loss: 0.0010
# Epoch 20/100
#  - 0s - loss: 0.0035 - val_loss: 0.0015
# Epoch 21/100
#  - 0s - loss: 0.0034 - val_loss: 6.8233e-04
# Epoch 22/100
#  - 0s - loss: 0.0033 - val_loss: 0.0014
# Epoch 23/100
#  - 0s - loss: 0.0033 - val_loss: 8.3442e-04
# Epoch 24/100
#  - 0s - loss: 0.0033 - val_loss: 0.0014
# Epoch 25/100
#  - 0s - loss: 0.0031 - val_loss: 2.1017e-04
# Epoch 26/100
#  - 0s - loss: 0.0032 - val_loss: 0.0011
# Epoch 27/100
#  - 0s - loss: 0.0029 - val_loss: 2.0357e-04
# Epoch 28/100
#  - 0s - loss: 0.0032 - val_loss: 8.1544e-04
# Epoch 29/100
#  - 0s - loss: 0.0030 - val_loss: 1.0225e-04
# Epoch 30/100
#  - 0s - loss: 0.0028 - val_loss: 7.3511e-04
# Epoch 31/100
#  - 0s - loss: 0.0029 - val_loss: 5.9470e-04
# Epoch 32/100
#  - 0s - loss: 0.0028 - val_loss: 0.0012
# Epoch 33/100
#  - 0s - loss: 0.0025 - val_loss: 7.2566e-04
# Epoch 34/100
#  - 0s - loss: 0.0029 - val_loss: 6.5251e-04
# Epoch 35/100
#  - 0s - loss: 0.0025 - val_loss: 3.1329e-04
# Epoch 36/100
#  - 0s - loss: 0.0025 - val_loss: 5.6467e-04
# Epoch 37/100
#  - 0s - loss: 0.0026 - val_loss: 6.6261e-04
# Epoch 38/100
#  - 0s - loss: 0.0025 - val_loss: 0.0013
# Epoch 39/100
#  - 0s - loss: 0.0024 - val_loss: 2.5028e-04
# Epoch 40/100
#  - 0s - loss: 0.0023 - val_loss: 3.2786e-04
# Epoch 41/100
#  - 0s - loss: 0.0024 - val_loss: 3.0435e-04
# Epoch 42/100
#  - 0s - loss: 0.0025 - val_loss: 8.4444e-04
# Epoch 43/100
#  - 0s - loss: 0.0024 - val_loss: 2.9013e-04
# Epoch 44/100
#  - 0s - loss: 0.0023 - val_loss: 1.9432e-04
# Epoch 45/100
#  - 0s - loss: 0.0021 - val_loss: 4.5533e-04
# Epoch 46/100
#  - 0s - loss: 0.0023 - val_loss: 5.1301e-04
# Epoch 47/100
#  - 0s - loss: 0.0022 - val_loss: 4.9043e-04
# Epoch 48/100
#  - 0s - loss: 0.0022 - val_loss: 3.1539e-04
# Epoch 49/100
#  - 0s - loss: 0.0020 - val_loss: 5.7623e-04
# Epoch 50/100
#  - 0s - loss: 0.0019 - val_loss: 6.0253e-05
# Epoch 51/100
#  - 0s - loss: 0.0022 - val_loss: 3.5731e-04
# Epoch 52/100
#  - 0s - loss: 0.0020 - val_loss: 9.3704e-04
# Epoch 53/100
#  - 0s - loss: 0.0018 - val_loss: 9.4934e-05
# Epoch 54/100
#  - 0s - loss: 0.0020 - val_loss: 7.9896e-04
# Epoch 55/100
#  - 0s - loss: 0.0019 - val_loss: 7.4956e-05
# Epoch 56/100
#  - 0s - loss: 0.0018 - val_loss: 1.2855e-05
# Epoch 57/100
#  - 0s - loss: 0.0019 - val_loss: 5.5893e-04
# Epoch 58/100
#  - 0s - loss: 0.0019 - val_loss: 2.0416e-04
# Epoch 59/100
#  - 0s - loss: 0.0017 - val_loss: 1.9483e-05
# Epoch 60/100
#  - 0s - loss: 0.0018 - val_loss: 6.5197e-04
# Epoch 61/100
#  - 0s - loss: 0.0018 - val_loss: 1.6660e-04
# Epoch 62/100
#  - 0s - loss: 0.0016 - val_loss: 8.2572e-04
# Epoch 63/100
#  - 0s - loss: 0.0018 - val_loss: 9.0343e-05
# Epoch 64/100
#  - 0s - loss: 0.0017 - val_loss: 9.3183e-04
# Epoch 65/100
#  - 0s - loss: 0.0017 - val_loss: 8.1252e-05
# Epoch 66/100
#  - 0s - loss: 0.0018 - val_loss: 7.3944e-04
# Epoch 67/100
#  - 0s - loss: 0.0015 - val_loss: 1.9928e-04
# Epoch 68/100
#  - 0s - loss: 0.0017 - val_loss: 8.2481e-04
# Epoch 69/100
#  - 0s - loss: 0.0015 - val_loss: 5.6942e-04
# Epoch 70/100
#  - 0s - loss: 0.0016 - val_loss: 3.6702e-04
# Epoch 71/100
#  - 0s - loss: 0.0016 - val_loss: 1.3575e-04
# Epoch 72/100
#  - 0s - loss: 0.0015 - val_loss: 5.2596e-04
# Epoch 73/100
#  - 0s - loss: 0.0015 - val_loss: 3.3177e-05
# Epoch 74/100
#  - 0s - loss: 0.0015 - val_loss: 2.2166e-04
# Epoch 75/100
#  - 0s - loss: 0.0016 - val_loss: 2.6154e-04
# Epoch 76/100
#  - 0s - loss: 0.0014 - val_loss: 9.5009e-06
# Epoch 77/100
#  - 0s - loss: 0.0016 - val_loss: 3.8752e-04
# Epoch 78/100
#  - 0s - loss: 0.0014 - val_loss: 3.8485e-05
# Epoch 79/100
#  - 0s - loss: 0.0013 - val_loss: 1.8643e-04
# Epoch 80/100
#  - 0s - loss: 0.0014 - val_loss: 1.0053e-04
# Epoch 81/100
#  - 0s - loss: 0.0014 - val_loss: 3.6163e-04
# Epoch 82/100
#  - 0s - loss: 0.0013 - val_loss: 3.9549e-04
# Epoch 83/100
#  - 0s - loss: 0.0013 - val_loss: 1.2501e-05
# Epoch 84/100
#  - 0s - loss: 0.0013 - val_loss: 4.1957e-04
# Epoch 85/100
#  - 0s - loss: 0.0014 - val_loss: 5.9364e-05
# Epoch 86/100
#  - 0s - loss: 0.0013 - val_loss: 4.2509e-04
# Epoch 87/100
#  - 0s - loss: 0.0012 - val_loss: 2.5965e-05
# Epoch 88/100
#  - 0s - loss: 0.0013 - val_loss: 2.0142e-04
# Epoch 89/100
#  - 0s - loss: 0.0013 - val_loss: 1.5697e-05
# Epoch 90/100
#  - 0s - loss: 0.0011 - val_loss: 5.4941e-05
# Epoch 91/100
#  - 0s - loss: 0.0013 - val_loss: 2.8913e-04
# Epoch 92/100
#  - 0s - loss: 0.0013 - val_loss: 4.7974e-05
# Epoch 93/100
#  - 0s - loss: 0.0012 - val_loss: 3.8496e-04
# Epoch 94/100
#  - 0s - loss: 0.0011 - val_loss: 1.7341e-04
# Epoch 95/100
#  - 0s - loss: 0.0012 - val_loss: 1.1185e-04
# Epoch 96/100
#  - 0s - loss: 0.0011 - val_loss: 3.0491e-04
# Epoch 97/100
#  - 0s - loss: 0.0012 - val_loss: 5.3430e-05
# Epoch 98/100
#  - 0s - loss: 0.0012 - val_loss: 3.7625e-04
# Epoch 99/100
#  - 0s - loss: 0.0012 - val_loss: 8.6861e-05
# Epoch 100/100
#  - 0s - loss: 0.0011 - val_loss: 1.7347e-04

# %% [markdown]
# ### Testing Model

# %%
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# %%
print(trainPredict)
# Out:
# [[ 1.00393939]
#  [ 1.00392962]
#  [ 1.00392652]
#  ...,
#  [ 0.29758152]
#  [ 0.29757866]
#  [ 0.29757577]]

# %% [markdown]
# ### Inverting predictions back to original form

# %%
trainPredict = scaler.inverse_transform(trainPredict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-2cdb9221bd27> in <module>()
# ----> 1 trainPredict = scaler.inverse_transform(trainPredict)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py in inverse_transform(self, X)
#     383         X = check_array(X, copy=self.copy, dtype=FLOAT_DTYPES)
#     384
# --> 385         X -= self.min_
#     386         X /= self.scale_
#     387         return X
#
# ValueError: non-broadcastable output operand with shape (5715,1) doesn't match the broadcast shape (5715,2)

# %%
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])


testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-d78378386909> in <module>()
# ----> 1 trainPredict = scaler.inverse_transform(trainPredict)
#       2 trainY = scaler.inverse_transform([trainY])
#       3
#       4
#       5 testPredict = scaler.inverse_transform(testPredict)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py in inverse_transform(self, X)
#     383         X = check_array(X, copy=self.copy, dtype=FLOAT_DTYPES)
#     384
# --> 385         X -= self.min_
#     386         X /= self.scale_
#     387         return X
#
# ValueError: non-broadcastable output operand with shape (5715,1) doesn't match the broadcast shape (5715,2)

# %%
predictions = lstm.predict_sequences_multiple(model, testX, 3, 3)
lstm.plot_results_multiple(predictions, testY, 3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-9a14b208e355> in <module>()
# ----> 1 predictions = lstm.predict_sequences_multiple(model, testX, 3, 3)
#       2 lstm.plot_results_multiple(predictions, testY, 3)
#
# NameError: name 'lstm' is not defined
